# %%
import tensorflow as tf
import tensorflow_datasets as tfds

# %%
# Load in data
dset, info = tfds.load('cifar10', with_info=True, as_supervised=True)
train_set = dset['train']

# %%
ds, ds_info = tfds.load('cifar10', split='test', with_info=True)
fig = tfds.show_examples(ds, ds_info)
fig
